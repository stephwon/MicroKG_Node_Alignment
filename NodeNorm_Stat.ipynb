# %%
#Set working directory
import os
os.chdir('/scratch1/sjw6257/MetaGen-Microbiome') 

# Install required packages
import pandas as pd
import yaml
import sys 
import csv
import json
import requests

# %%
import itertools
from itertools import product
from tqdm.notebook import tqdm
from collections import defaultdict

# %%
## Set API endpoint
url = "https://nodenormalization-sri.renci.org/1.5/get_normalized_nodes"
headers = {
    "Content-Type": "application/json"
}

# %%
## POST request to the API
response = requests.post(url, headers=headers, json=curies_json)

# Check Response status
if response.status_code == 200:
    print("Request was successful! \n")
    
    # Parse and display the JSON response
    normalized_data = response.json()
    #print(normalized_data)  # Pretty-print the JSON response (Optional)
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text)
# Out:
# Request was successful!

# %%
### End of Node Normalization ###

# %% [markdown]
# ## Node Normalization Result
# Given that some CURIES from Node Normalizer result do not contain name(s), I added MicrobiomeKG `name` column (from TSV file) to `df` for analysis purpose.
# The MicrobiomeKG `name` will not be used for Node Synonymizer step in the pipe line.

# %%
f_path = 'node_norm_with_microKG_names.csv'
df_data = pd.read_csv(f_path, sep=',')

# %%
## MicroKG ID vs. NN Identifier (ID)
comparison = df_data['CURIE'] == df_data['Identifier']
false_rows = df_data[~comparison & df_data.notna().all(axis=1)]

# Note: Does not include rows with NaN values
false_rows
# Out:
#                  CURIE      Identifier     Name  \
# 61    UniProtKB:Q9GZT9  NCBIGene:54583    EGLN1
# 161   UniProtKB:P98198  NCBIGene:57198   ATP8B2
# 356   UniProtKB:P06239   NCBIGene:3932      LCK
# 396   UniProtKB:Q9UBZ9  NCBIGene:51455     REV1
# 619   UniProtKB:Q9Y251  NCBIGene:10855     HPSE
# 742   UniProtKB:P45983   NCBIGene:5599    MAPK8
# 1106  UniProtKB:P10398    NCBIGene:369     ARAF
# 1223  UniProtKB:Q9Y4X5  NCBIGene:25820    ARIH1
# 1457  UniProtKB:P00568    NCBIGene:203      AK1
# 1721  UniProtKB:Q02318   NCBIGene:1593  CYP27A1
# 1888  UniProtKB:P42772   NCBIGene:1030   CDKN2B
# 2012  UniProtKB:P49459   NCBIGene:7319    UBE2A
# 2417  UniProtKB:O15217   NCBIGene:2941    GSTA4
# 2449  UniProtKB:P54819    NCBIGene:204      AK2
# 2480  UniProtKB:P62140   NCBIGene:5500   PPP1CB
# 2679  UniProtKB:P48730   NCBIGene:1453   CSNK1D
# 2730  UniProtKB:P49585   NCBIGene:5130   PCYT1A
# 2836  UniProtKB:P54753   NCBIGene:2049    EPHB3
# 2850  UniProtKB:P15085   NCBIGene:1357     CPA1
# 2921  UniProtKB:P28062   NCBIGene:5696    PSMB8
# 2960  UniProtKB:P06732   NCBIGene:1158      CKM
# 3015  UniProtKB:Q9Y2R4  NCBIGene:11056    DDX52
# 3260  UniProtKB:P19474   NCBIGene:6737   TRIM21
# 3283  UniProtKB:Q8N6R0  NCBIGene:51603  METTL13
# 3677  UniProtKB:P01133   NCBIGene:1950      EGF
# 3708  UniProtKB:Q8IYT4  NCBIGene:83473  KATNAL2
# 3803  UniProtKB:Q15022  NCBIGene:23512    SUZ12
# 3885  UniProtKB:Q13231   NCBIGene:1118    CHIT1
# 3959  UniProtKB:O15327   NCBIGene:8821   INPP4B
# 3965  UniProtKB:O75342    NCBIGene:242  ALOX12B
# 4119  UniProtKB:P16930   NCBIGene:2184      FAH
# 4396  UniProtKB:P30085  NCBIGene:51727    CMPK1
# 4552  UniProtKB:P29466    NCBIGene:834    CASP1
# 4578  UniProtKB:Q95460   NCBIGene:3140      MR1
# 4599  UniProtKB:O00141   NCBIGene:6446     SGK1
# 4650  UniProtKB:Q9H7M9  NCBIGene:64115     VSIR
# 5030  UniProtKB:Q9HBU6  NCBIGene:55500    ETNK1
# 5049  UniProtKB:Q03426   NCBIGene:4598      MVK
#
#                                  Equivalent Identifiers  \
# 61    NCBIGene:54583, ENSEMBL:ENSG00000135766, HGNC:...
# 161   NCBIGene:57198, ENSEMBL:ENSG00000143515, HGNC:...
# 356   NCBIGene:3932, ENSEMBL:ENSG00000182866, HGNC:6...
# 396   NCBIGene:51455, ENSEMBL:ENSG00000135945, HGNC:...
# 619   NCBIGene:10855, ENSEMBL:ENSG00000173083, HGNC:...
# 742   NCBIGene:5599, ENSEMBL:ENSG00000107643, HGNC:6...
# 1106  NCBIGene:369, ENSEMBL:ENSG00000078061, HGNC:64...
# 1223  NCBIGene:25820, ENSEMBL:ENSG00000166233, HGNC:...
# 1457  NCBIGene:203, ENSEMBL:ENSG00000106992, HGNC:36...
# 1721  NCBIGene:1593, ENSEMBL:ENSG00000135929, HGNC:2...
# 1888  NCBIGene:1030, ENSEMBL:ENSG00000147883, HGNC:1...
# 2012  NCBIGene:7319, ENSEMBL:ENSG00000077721, HGNC:1...
# 2417  NCBIGene:2941, ENSEMBL:ENSG00000170899, HGNC:4...
# 2449  NCBIGene:204, ENSEMBL:ENSG00000004455, HGNC:36...
# 2480  NCBIGene:5500, ENSEMBL:ENSG00000213639, HGNC:9...
# 2679  NCBIGene:1453, ENSEMBL:ENSG00000141551, HGNC:2...
# 2730  NCBIGene:5130, ENSEMBL:ENSG00000161217, HGNC:8...
# 2836  NCBIGene:2049, ENSEMBL:ENSG00000182580, HGNC:3...
# 2850  NCBIGene:1357, ENSEMBL:ENSG00000091704, HGNC:2...
# 2921  NCBIGene:5696, ENSEMBL:ENSG00000204264, HGNC:9...
# 2960  NCBIGene:1158, ENSEMBL:ENSG00000104879, HGNC:1...
# 3015  NCBIGene:11056, ENSEMBL:ENSG00000278053, HGNC:...
# 3260  NCBIGene:6737, ENSEMBL:ENSG00000132109, HGNC:1...
# 3283  NCBIGene:51603, ENSEMBL:ENSG00000010165, HGNC:...
# 3677  NCBIGene:1950, ENSEMBL:ENSG00000138798, HGNC:3...
# 3708  NCBIGene:83473, ENSEMBL:ENSG00000167216, HGNC:...
# 3803  NCBIGene:23512, ENSEMBL:ENSG00000178691, HGNC:...
# 3885  NCBIGene:1118, ENSEMBL:ENSG00000133063, HGNC:1...
# 3959  NCBIGene:8821, ENSEMBL:ENSG00000109452, HGNC:6...
# 3965  NCBIGene:242, ENSEMBL:ENSG00000179477, HGNC:43...
# 4119  NCBIGene:2184, ENSEMBL:ENSG00000103876, HGNC:3...
# 4396  NCBIGene:51727, ENSEMBL:ENSG00000162368, HGNC:...
# 4552  NCBIGene:834, ENSEMBL:ENSG00000137752, HGNC:14...
# 4578  NCBIGene:3140, ENSEMBL:ENSG00000153029, HGNC:4...
# 4599  NCBIGene:6446, ENSEMBL:ENSG00000118515, HGNC:1...
# 4650  NCBIGene:64115, ENSEMBL:ENSG00000107738, HGNC:...
# 5030  NCBIGene:55500, ENSEMBL:ENSG00000139163, HGNC:...
# 5049  NCBIGene:4598, ENSEMBL:ENSG00000110921, HGNC:7...
#
#                                         Equivalent Name  \
# 61    EGLN1, No label, EGLN1, No label, EGLN1 gene, ...
# 161   ATP8B2, No label, ATP8B2, No label, ATP8B2 gen...
# 356   LCK, No label, LCK, No label, LCK gene, A0A0S2...
# 396   REV1, No label, REV1, No label, REV1 gene, Q49...
# 619   HPSE, No label, HPSE, No label, HPSE gene, HPS...
# 742   MAPK8, No label, MAPK8, No label, MAPK8 gene, ...
# 1106  ARAF, No label, ARAF, No label, ARAF gene, A0A...
# 1223  ARIH1, No label, ARIH1, No label, ARIH1 gene, ...
# 1457  AK1, No label, AK1, No label, AK1 gene, KAD1_H...
# 1721  CYP27A1, No label, CYP27A1, No label, CYP27A1 ...
# 1888  CDKN2B, No label, CDKN2B, No label, CDKN2B gen...
# 2012  UBE2A, No label, UBE2A, No label, UBE2A gene, ...
# 2417  GSTA4, No label, GSTA4, No label, GSTA4 gene, ...
# 2449  AK2, No label, AK2, No label, AK2 gene, A0A140...
# 2480  PPP1CB, No label, PPP1CB, No label, PPP1CB gen...
# 2679  CSNK1D, No label, CSNK1D, No label, CSNK1D gen...
# 2730  PCYT1A, No label, PCYT1A, No label, PCYT1A gen...
# 2836  EPHB3, No label, EPHB3, No label, EPHB3 gene, ...
# 2850  CPA1, No label, CPA1, No label, CPA1 gene, CBP...
# 2921  PSMB8, No label, PSMB8, No label, PSMB8 gene, ...
# 2960  CKM, No label, CKM, No label, CKM gene, B2R892...
# 3015  DDX52, No label, DDX52, No label, DDX52 gene, ...
# 3260  TRIM21, No label, TRIM21, No label, TRIM21 gen...
# 3283  METTL13, No label, METTL13, No label, METTL13 ...
# 3677  EGF, No label, EGF, No label, EGF gene, EGF_HU...
# 3708  KATNAL2, No label, KATNAL2, No label, KATNAL2 ...
# 3803  SUZ12, No label, SUZ12, No label, SUZ12 gene, ...
# 3885  CHIT1, No label, CHIT1, No label, CHIT1 gene, ...
# 3959  INPP4B, No label, INPP4B, No label, INPP4B gen...
# 3965  ALOX12B, No label, ALOX12B, No label, ALOX12B ...
# 4119  FAH, No label, FAH, No label, FAH gene, A0A384...
# 4396  CMPK1, No label, CMPK1, No label, CMPK1 gene, ...
# 4552  CASP1, No label, CASP1, No label, CASP1 gene, ...
# 4578  MR1, No label, MR1, No label, MR1 gene, HMR1_H...
# 4599  SGK1, No label, SGK1, No label, SGK1 gene, B7Z...
# 4650  VSIR, No label, VSIR, No label, VSIR gene, VIS...
# 5030  ETNK1, No label, ETNK1, No label, ETNK1 gene, ...
# 5049  MVK, No label, MVK, No label, MVK gene, B2RDU6...
#
#                                                   Types  \
# 61    biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 161   biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 356   biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 396   biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 619   biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 742   biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 1106  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 1223  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 1457  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 1721  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 1888  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2012  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2417  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2449  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2480  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2679  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2730  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2836  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2850  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2921  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 2960  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3015  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3260  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3283  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3677  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3708  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3803  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3885  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3959  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 3965  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 4119  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 4396  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 4552  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 4578  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 4599  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 4650  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 5030  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 5049  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
#
#                                            MicroKG_Name
# 61               EGLN1_HUMAN Egl nine homolog 1 (sprot)
# 161   AT8B2_HUMAN Phospholipid-transporting ATPase I...
# 356       LCK_HUMAN Tyrosine-protein kinase Lck (sprot)
# 396          REV1_HUMAN DNA repair protein REV1 (sprot)
# 619                       HPSE_HUMAN Heparanase (sprot)
# 742   MK08_HUMAN Mitogen-activated protein kinase 8 ...
# 1106  ARAF_HUMAN Serine/threonine-protein kinase A-R...
# 1223  ARI1_HUMAN E3 ubiquitin-protein ligase ARIH1 (...
# 1457    KAD1_HUMAN Adenylate kinase isoenzyme 1 (sprot)
# 1721  CP27A_HUMAN Sterol 26-hydroxylase, mitochondri...
# 1888  CDN2B_HUMAN Cyclin-dependent kinase 4 inhibito...
# 2012  UBE2A_HUMAN Ubiquitin-conjugating enzyme E2 A ...
# 2417   GSTA4_HUMAN Glutathione S-transferase A4 (sprot)
# 2449  KAD2_HUMAN Adenylate kinase 2, mitochondrial (...
# 2480  PP1B_HUMAN Serine/threonine-protein phosphatas...
# 2679   KC1D_HUMAN Casein kinase I isoform delta (sprot)
# 2730  PCY1A_HUMAN Choline-phosphate cytidylyltransfe...
# 2836       EPHB3_HUMAN Ephrin type-B receptor 3 (sprot)
# 2850            CBPA1_HUMAN Carboxypeptidase A1 (sprot)
# 2921  PSB8_HUMAN Proteasome subunit beta type-8 (sprot)
# 2960          KCRM_HUMAN Creatine kinase M-type (sprot)
# 3015  DDX52_HUMAN Probable ATP-dependent RNA helicas...
# 3260  RO52_HUMAN E3 ubiquitin-protein ligase TRIM21 ...
# 3283  EFNMT_HUMAN eEF1A lysine and N-terminal methyl...
# 3677      EGF_HUMAN Pro-epidermal growth factor (sprot)
# 3708  KATL2_HUMAN Katanin p60 ATPase-containing subu...
# 3803         SUZ12_HUMAN Polycomb protein SUZ12 (sprot)
# 3885              CHIT1_HUMAN Chitotriosidase-1 (sprot)
# 3959  INP4B_HUMAN Inositol polyphosphate 4-phosphata...
# 3965  LX12B_HUMAN Arachidonate 12-lipoxygenase, 12R-...
# 4119             FAAA_HUMAN Fumarylacetoacetase (sprot)
# 4396                   KCY_HUMAN UMP-CMP kinase (sprot)
# 4552                      CASP1_HUMAN Caspase-1 (sprot)
# 4578  HMR1_HUMAN Major histocompatibility complex cl...
# 4599  SGK1_HUMAN Serine/threonine-protein kinase Sgk...
# 4650  VISTA_HUMAN V-type immunoglobulin domain-conta...
# 5030           EKI1_HUMAN Ethanolamine kinase 1 (sprot)
# 5049               KIME_HUMAN Mevalonate kinase (sprot)

# %%
## Compare NN `Name` to MicroKG `name`
comparison2 = df_data['Name'] == df_data['MicroKG_Name']
false = df_data[~comparison2 & df_data.notna().all(axis=1)]

# Note: This does not include rows where `Name` has NaN
false
# Out:
#                  CURIE      Identifier  \
# 17         EC:3.1.12.1     EC:3.1.12.1
# 61    UniProtKB:Q9GZT9  NCBIGene:54583
# 161   UniProtKB:P98198  NCBIGene:57198
# 333       EC:1.1.1.292    EC:1.1.1.292
# 341         EC:1.6.1.1      EC:1.6.1.1
# ...                ...             ...
# 4922       EC:3.5.1.46     EC:3.5.1.46
# 4990      EC:3.5.1.101    EC:3.5.1.101
# 5030  UniProtKB:Q9HBU6  NCBIGene:55500
# 5049  UniProtKB:Q03426   NCBIGene:4598
# 5224      EC:1.1.1.281    EC:1.1.1.281
#
#                                                    Name  \
# 17    "5' to 3' exodeoxyribonuclease (nucleoside 3'-...
# 61                                                EGLN1
# 161                                              ATP8B2
# 333   "1,5-anhydro-D-fructose reductase (1,5-anhydro...
# 341          "NAD(P)(+) transhydrogenase (Si-specific)"
# ...                                                 ...
# 4922           "6-aminohexanoate-oligomer exohydrolase"
# 4990                        "L-proline amide hydrolase"
# 5030                                              ETNK1
# 5049                                                MVK
# 5224        "GDP-4-dehydro-6-deoxy-D-mannose reductase"
#
#                                  Equivalent Identifiers  \
# 17                                          EC:3.1.12.1
# 61    NCBIGene:54583, ENSEMBL:ENSG00000135766, HGNC:...
# 161   NCBIGene:57198, ENSEMBL:ENSG00000143515, HGNC:...
# 333                                        EC:1.1.1.292
# 341                                          EC:1.6.1.1
# ...                                                 ...
# 4922                                        EC:3.5.1.46
# 4990                                       EC:3.5.1.101
# 5030  NCBIGene:55500, ENSEMBL:ENSG00000139163, HGNC:...
# 5049  NCBIGene:4598, ENSEMBL:ENSG00000110921, HGNC:7...
# 5224                                       EC:1.1.1.281
#
#                                         Equivalent Name  \
# 17    "5' to 3' exodeoxyribonuclease (nucleoside 3'-...
# 61    EGLN1, No label, EGLN1, No label, EGLN1 gene, ...
# 161   ATP8B2, No label, ATP8B2, No label, ATP8B2 gen...
# 333   "1,5-anhydro-D-fructose reductase (1,5-anhydro...
# 341          "NAD(P)(+) transhydrogenase (Si-specific)"
# ...                                                 ...
# 4922           "6-aminohexanoate-oligomer exohydrolase"
# 4990                        "L-proline amide hydrolase"
# 5030  ETNK1, No label, ETNK1, No label, ETNK1 gene, ...
# 5049  MVK, No label, MVK, No label, MVK gene, B2RDU6...
# 5224        "GDP-4-dehydro-6-deoxy-D-mannose reductase"
#
#                                                   Types  \
# 17    biolink:MolecularActivity, biolink:Occurrent, ...
# 61    biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 161   biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 333   biolink:MolecularActivity, biolink:Occurrent, ...
# 341   biolink:MolecularActivity, biolink:Occurrent, ...
# ...                                                 ...
# 4922  biolink:MolecularActivity, biolink:Occurrent, ...
# 4990  biolink:MolecularActivity, biolink:Occurrent, ...
# 5030  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 5049  biolink:Gene, biolink:GeneOrGeneProduct, bioli...
# 5224  biolink:MolecularActivity, biolink:Occurrent, ...
#
#                                            MicroKG_Name
# 17                                                    \
# 61               EGLN1_HUMAN Egl nine homolog 1 (sprot)
# 161   AT8B2_HUMAN Phospholipid-transporting ATPase I...
# 333                                                   \
# 341                                                   \
# ...                                                 ...
# 4922                                                  \
# 4990                                                  \
# 5030           EKI1_HUMAN Ethanolamine kinase 1 (sprot)
# 5049               KIME_HUMAN Mevalonate kinase (sprot)
# 5224                                                  \
#
# [87 rows x 7 columns]

# %%
# Missing Name and/or Identifier
missing_name_or_identifier = df_data[df_data['Name'].isnull() | df_data['Identifier'].isnull()]
missing_name_or_identifier
# Out:
#                   CURIE Identifier Name Equivalent Identifiers  \
# 9     NCBIGene:69618870        NaN  NaN                    NaN
# 123   NCBIGene:69622190        NaN  NaN                    NaN
# 157   NCBIGene:56333716        NaN  NaN                    NaN
# 194   NCBIGene:70044589        NaN  NaN                    NaN
# 205   NCBIGene:86883341        NaN  NaN                    NaN
# ...                 ...        ...  ...                    ...
# 5187         GO:0140868        NaN  NaN                    NaN
# 5229  NCBIGene:60545508        NaN  NaN                    NaN
# 5238  NCBIGene:57313172        NaN  NaN                    NaN
# 5310  NCBIGene:67459097        NaN  NaN                    NaN
# 5318  NCBIGene:57314851        NaN  NaN                    NaN
#
#      Equivalent Name Types                                       MicroKG_Name
# 9                NaN   NaN                                               frlB
# 123              NaN   NaN                                               aftC
# 157              NaN   NaN                                       I501_RS09505
# 194              NaN   NaN                                               hpdB
# 205              NaN   NaN                                               arnB
# ...              ...   ...                                                ...
# 5187             NaN   NaN  4,4'-diapophytoene desaturase (4,4'-diapolycop...
# 5229             NaN   NaN                                               ftsL
# 5238             NaN   NaN                                               mtnK
# 5310             NaN   NaN                                     A39M_RS0122745
# 5318             NaN   NaN                                               menI
#
# [121 rows x 7 columns]

# %%
missing_both = df_data[df_data['Name'].isnull() & df_data['Identifier'].isnull()]
missing_both
# Out:
#                   CURIE Identifier Name Equivalent Identifiers  \
# 9     NCBIGene:69618870        NaN  NaN                    NaN
# 123   NCBIGene:69622190        NaN  NaN                    NaN
# 157   NCBIGene:56333716        NaN  NaN                    NaN
# 194   NCBIGene:70044589        NaN  NaN                    NaN
# 205   NCBIGene:86883341        NaN  NaN                    NaN
# ...                 ...        ...  ...                    ...
# 5187         GO:0140868        NaN  NaN                    NaN
# 5229  NCBIGene:60545508        NaN  NaN                    NaN
# 5238  NCBIGene:57313172        NaN  NaN                    NaN
# 5310  NCBIGene:67459097        NaN  NaN                    NaN
# 5318  NCBIGene:57314851        NaN  NaN                    NaN
#
#      Equivalent Name Types                                       MicroKG_Name
# 9                NaN   NaN                                               frlB
# 123              NaN   NaN                                               aftC
# 157              NaN   NaN                                       I501_RS09505
# 194              NaN   NaN                                               hpdB
# 205              NaN   NaN                                               arnB
# ...              ...   ...                                                ...
# 5187             NaN   NaN  4,4'-diapophytoene desaturase (4,4'-diapolycop...
# 5229             NaN   NaN                                               ftsL
# 5238             NaN   NaN                                               mtnK
# 5310             NaN   NaN                                     A39M_RS0122745
# 5318             NaN   NaN                                               menI
#
# [121 rows x 7 columns]
